# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mydataset = pd.read_excel(r'C:\Users\user\OneDrive - International Institute of Information Technology\Desktop\jupyter\codes\cleaned_data.xlsx')

# %%
# According to Attribute Oriented Induction, data generalization can be performed in either of two ways : 1. Attribute removal 2. Attribute genralization.
# First we will perform Attribute removal, we remove the attributes that have large set of distinct values or its concepts can be expresses by other attributes they can be removed.
# According to the above rule we remove some attributes from the data.

char_rules = mydataset.copy()
char_rules.drop(char_rules.columns[[0,1,5,6,7,8,10,13,14,15,16,19,20,21,23,24,26,28,29,31]], axis = 1, inplace = True)

char_rules['Price_per_unit_area'] = char_rules['Price_per_unit_area'].apply(lambda x : int(str(x).replace(",","")))
char_rules['Size'] = char_rules['Size'].apply(lambda x: int(x[:-6].replace(",","")) )
char_rules['Price'] = char_rules['Price'].apply(lambda x: float(x.replace(",","")))

# %%
char_rules
# Out:
#        Property_type     Property_status  Price_per_unit_area  \
# 0          Apartment  Under Construction                 4285
# 1          Apartment  Under Construction                 7000
# 2          Apartment       Ready to move                 5752
# 3          Apartment       Ready to move                 2486
# 4          Apartment  Under Construction                 5324
# ...              ...                 ...                  ...
# 143703     Apartment  Under Construction                 9826
# 143704     Apartment  Under Construction                 8568
# 143705     Apartment  Under Construction                 9861
# 143706     Apartment  Under Construction                 8813
# 143707     Apartment  Under Construction                 9859
#
#        Property_building_status  City_name No_of_BHK       Price  Size  \
# 0                        ACTIVE  Ahmedabad     3 BHK   7500000.0  1750
# 1                        ACTIVE  Ahmedabad     4 BHK  23688000.0  3384
# 2                        ACTIVE  Ahmedabad     3 BHK  13200840.0  2295
# 3                        ACTIVE  Ahmedabad     2 BHK   2283000.0   918
# 4                        ACTIVE  Ahmedabad     3 BHK   9371000.0  1760
# ...                         ...        ...       ...         ...   ...
# 143703                   ACTIVE     Mumbai     1 BHK   3400000.0   346
# 143704                   ACTIVE     Mumbai     1 BHK   3650000.0   426
# 143705                   ACTIVE     Mumbai     1 BHK   3550000.0   360
# 143706                   ACTIVE     Mumbai     2 BHK   5200000.0   590
# 143707                   ACTIVE     Mumbai     1 BHK   3529577.0   358
#
#        is_furnished  is_RERA_registered  is_ready_to_move  is_studio
# 0       Unfurnished                True             False      False
# 1       Unfurnished                True             False      False
# 2       Unfurnished               False              True      False
# 3       Unfurnished               False              True      False
# 4       Unfurnished                True             False      False
# ...             ...                 ...               ...        ...
# 143703  Unfurnished                True             False      False
# 143704  Unfurnished                True             False      False
# 143705  Unfurnished                True             False      False
# 143706  Unfurnished                True             False      False
# 143707  Unfurnished                True             False      False
#
# [143708 rows x 12 columns]

# %%
# Now coming into Attribute generalization.
# 1. We have taken Active properties which are under construction and ready to move.

stat = char_rules[(char_rules['Property_building_status'] != 'ACTIVE') ].index
char_rules.drop(stat, inplace = True)
char_rules
# Out:
#        Property_type     Property_status  Price_per_unit_area  \
# 0          Apartment  Under Construction                 4285
# 1          Apartment  Under Construction                 7000
# 2          Apartment       Ready to move                 5752
# 3          Apartment       Ready to move                 2486
# 4          Apartment  Under Construction                 5324
# ...              ...                 ...                  ...
# 143703     Apartment  Under Construction                 9826
# 143704     Apartment  Under Construction                 8568
# 143705     Apartment  Under Construction                 9861
# 143706     Apartment  Under Construction                 8813
# 143707     Apartment  Under Construction                 9859
#
#        Property_building_status  City_name No_of_BHK       Price  Size  \
# 0                        ACTIVE  Ahmedabad     3 BHK   7500000.0  1750
# 1                        ACTIVE  Ahmedabad     4 BHK  23688000.0  3384
# 2                        ACTIVE  Ahmedabad     3 BHK  13200840.0  2295
# 3                        ACTIVE  Ahmedabad     2 BHK   2283000.0   918
# 4                        ACTIVE  Ahmedabad     3 BHK   9371000.0  1760
# ...                         ...        ...       ...         ...   ...
# 143703                   ACTIVE     Mumbai     1 BHK   3400000.0   346
# 143704                   ACTIVE     Mumbai     1 BHK   3650000.0   426
# 143705                   ACTIVE     Mumbai     1 BHK   3550000.0   360
# 143706                   ACTIVE     Mumbai     2 BHK   5200000.0   590
# 143707                   ACTIVE     Mumbai     1 BHK   3529577.0   358
#
#        is_furnished  is_RERA_registered  is_ready_to_move  is_studio
# 0       Unfurnished                True             False      False
# 1       Unfurnished                True             False      False
# 2       Unfurnished               False              True      False
# 3       Unfurnished               False              True      False
# 4       Unfurnished                True             False      False
# ...             ...                 ...               ...        ...
# 143703  Unfurnished                True             False      False
# 143704  Unfurnished                True             False      False
# 143705  Unfurnished                True             False      False
# 143706  Unfurnished                True             False      False
# 143707  Unfurnished                True             False      False
#
# [143538 rows x 12 columns]

# %%
temp = char_rules.copy()

# Next we classify cities Hyderabad, Chennai, Mumbai, Bangalore has Technology cities and remaining has other cities.
# Next we classify buildings with range of price per unit area 1. [100, 10000] -> Budeget 2. [10000, 50000] -> Luxury 3. [50000, 100000] -> Ultra Luxury
char_rules['City_name'] = np.where((char_rules['City_name'] == 'Hyderabad') | (char_rules['City_name'] == 'Chennai') | (char_rules['City_name'] == 'Bangalore' ) | (char_rules['City_name'] == 'Mumbai'), 'Technology Cities', 'Other Cities')
conditions = [(char_rules['Price_per_unit_area'] > 100) & (char_rules['Price_per_unit_area'] < 10000),
              (char_rules['Price_per_unit_area'] >= 10000) & (char_rules['Price_per_unit_area'] < 50000),
              (char_rules['Price_per_unit_area'] >= 50000) & (char_rules['Price_per_unit_area'] < 100000),
             ]

values = ['Budget', 'Luxury', 'Ultra Luxury']
char_rules['Price_per_unit_area'] = np.select(conditions, values)
    
char_rules
# Out:
#        Property_type     Property_status Price_per_unit_area  \
# 0          Apartment  Under Construction              Budget
# 1          Apartment  Under Construction              Budget
# 2          Apartment       Ready to move              Budget
# 3          Apartment       Ready to move              Budget
# 4          Apartment  Under Construction              Budget
# ...              ...                 ...                 ...
# 143703     Apartment  Under Construction              Budget
# 143704     Apartment  Under Construction              Budget
# 143705     Apartment  Under Construction              Budget
# 143706     Apartment  Under Construction              Budget
# 143707     Apartment  Under Construction              Budget
#
#        Property_building_status          City_name No_of_BHK       Price  \
# 0                        ACTIVE       Other Cities     3 BHK   7500000.0
# 1                        ACTIVE       Other Cities     4 BHK  23688000.0
# 2                        ACTIVE       Other Cities     3 BHK  13200840.0
# 3                        ACTIVE       Other Cities     2 BHK   2283000.0
# 4                        ACTIVE       Other Cities     3 BHK   9371000.0
# ...                         ...                ...       ...         ...
# 143703                   ACTIVE  Technology Cities     1 BHK   3400000.0
# 143704                   ACTIVE  Technology Cities     1 BHK   3650000.0
# 143705                   ACTIVE  Technology Cities     1 BHK   3550000.0
# 143706                   ACTIVE  Technology Cities     2 BHK   5200000.0
# 143707                   ACTIVE  Technology Cities     1 BHK   3529577.0
#
#         Size is_furnished  is_RERA_registered  is_ready_to_move  is_studio
# 0       1750  Unfurnished                True             False      False
# 1       3384  Unfurnished                True             False      False
# 2       2295  Unfurnished               False              True      False
# 3        918  Unfurnished               False              True      False
# 4       1760  Unfurnished                True             False      False
# ...      ...          ...                 ...               ...        ...
# 143703   346  Unfurnished                True             False      False
# 143704   426  Unfurnished                True             False      False
# 143705   360  Unfurnished                True             False      False
# 143706   590  Unfurnished                True             False      False
# 143707   358  Unfurnished                True             False      False
#
# [143538 rows x 12 columns]

# %%
tech_cities_ready = temp[((temp['City_name'] == "Bangalore") | (temp['City_name'] == "Chennai") | (temp['City_name'] == "Hyderabad") | (temp['City_name'] == "Mumbai") ) & (temp['Property_status'] == 'Ready to move')]

plt.title("No of ready to move properties in cities Bangalore,Chennai, Hyderabad and Mumbai")
plt.hist(tech_cities_ready['City_name'])
plt.xticks(rotation="70")
plt.xlabel("Cities")
plt.ylabel("No of ready to move properties")
plt.show()

# %%
# Visualizing the trend of property price VS property size in Technology cities that are ready to move

plt.title("Bangalore")
plt.scatter(tech_cities_ready[tech_cities_ready.City_name == "Bangalore"]['Size'],tech_cities_ready[tech_cities_ready.City_name=="Bangalore"]['Price'],color="red")
plt.xlabel("Size in sq ft")
plt.ylabel("Price")
plt.show()

plt.title("Hyderabad")
plt.scatter(tech_cities_ready[tech_cities_ready.City_name == "Hyderabad"]['Size'],tech_cities_ready[tech_cities_ready.City_name=="Hyderabad"]['Price'],color="blue")
plt.xlabel("Size in sq ft")
plt.ylabel("Price")
plt.show()

plt.title("Chennai")
plt.scatter(tech_cities_ready[tech_cities_ready.City_name == "Chennai"]['Size'],tech_cities_ready[tech_cities_ready.City_name=="Chennai"]['Price'],color="green")
plt.xlabel("Size in sq ft")
plt.ylabel("Price")
plt.show()

plt.title("Mumbai")
plt.scatter(tech_cities_ready[tech_cities_ready.City_name == "Mumbai"]['Size'],tech_cities_ready[tech_cities_ready.City_name=="Mumbai"]['Price'],color="orange")
plt.xlabel("Size in sq ft")
plt.ylabel("Price")
plt.show()

# %%
# Now let us visualize the average price per unit area in each of the city, so that the investors can know the affordable cities for investing on large size properties.
city_groupby = tech_cities_ready[['City_name','Price_per_unit_area']].groupby(['City_name']).mean()
puas = city_groupby['Price_per_unit_area']
least_pua_cities = city_groupby.index

plt.bar(least_pua_cities,puas)
plt.xticks(rotation = 70)
plt.xlabel("Cities")
plt.ylabel("Avg price per unit area")
plt.title("Average Price per unit area")
# Out:
# Text(0.5, 1.0, 'Average Price per unit area')

# %%
conditions = [(temp['Price_per_unit_area'] > 100) & (temp['Price_per_unit_area'] < 10000),
              (temp['Price_per_unit_area'] >= 10000) & (temp['Price_per_unit_area'] < 50000),
              (temp['Price_per_unit_area'] >= 50000) & (temp['Price_per_unit_area'] < 100000),
             ]

values = ['Budget', 'Luxury', 'Ultra Luxury']
temp['Price_per_unit_area'] = np.select(conditions, values)

other_cities_ready = temp[((temp['City_name'] == "Ahmedabad") | (temp['City_name'] == "Kolkata") | (temp['City_name'] == "Lucknow") | (temp['City_name'] == "Delhi") ) & (temp['Price_per_unit_area'] == "Luxury") & (temp['Property_status'] == "Under Construction")]
#other_cities_ready


plt.title("No of properties with range of Price per unit are in Luxury range in cities Ahmedabad, Kolkata, Lucknow, Delhi")
plt.hist(other_cities_ready['City_name'])
plt.xticks(rotation = "70")
plt.xlabel("Cities")
# plt.ylabel("No of properties with range of Price per unit are in Luxury range")
plt.show()
