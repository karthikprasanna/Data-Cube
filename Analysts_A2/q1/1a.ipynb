# %%
import numpy as np
import pandas as pd

pd.options.mode.chained_assignment = None   # default='warn'
data = pd.read_excel('cleaned_data.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [50], in <module>
#       2 import pandas as pd
#       4 pd.options.mode.chained_assignment = None   # default='warn'
# ----> 5 data = pd.read_excel('cleaned_data.xlsx')
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/excel/_base.py:465, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#     464 try:
# --> 465     data = io.parse(
#     466         sheet_name=sheet_name,
#     467         header=header,
#     468         names=names,
#     469         index_col=index_col,
#     470         usecols=usecols,
#     471         squeeze=squeeze,
#     472         dtype=dtype,
#     473         converters=converters,
#     474         true_values=true_values,
#     475         false_values=false_values,
#     476         skiprows=skiprows,
#     477         nrows=nrows,
#     478         na_values=na_values,
#     479         keep_default_na=keep_default_na,
#     480         na_filter=na_filter,
#     481         verbose=verbose,
#     482         parse_dates=parse_dates,
#     483         date_parser=date_parser,
#     484         thousands=thousands,
#     485         decimal=decimal,
#     486         comment=comment,
#     487         skipfooter=skipfooter,
#     488         convert_float=convert_float,
#     489         mangle_dupe_cols=mangle_dupe_cols,
#     490     )
#     491 finally:
#     492     # make sure to close opened file handles
#     493     if should_close:
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/excel/_base.py:1458, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#    1424 def parse(
#    1425     self,
#    1426     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1445     **kwds,
#    1446 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1447     """
#    1448     Parse specified sheet(s) into a DataFrame.
#    1449
#    (...)
#    1456         DataFrame from the passed in Excel file.
#    1457     """
# -> 1458     return self._reader.parse(
#    1459         sheet_name=sheet_name,
#    1460         header=header,
#    1461         names=names,
#    1462         index_col=index_col,
#    1463         usecols=usecols,
#    1464         squeeze=squeeze,
#    1465         converters=converters,
#    1466         true_values=true_values,
#    1467         false_values=false_values,
#    1468         skiprows=skiprows,
#    1469         nrows=nrows,
#    1470         na_values=na_values,
#    1471         parse_dates=parse_dates,
#    1472         date_parser=date_parser,
#    1473         thousands=thousands,
#    1474         comment=comment,
#    1475         skipfooter=skipfooter,
#    1476         convert_float=convert_float,
#    1477         mangle_dupe_cols=mangle_dupe_cols,
#    1478         **kwds,
#    1479     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/excel/_base.py:638, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     635 else:  # assume an integer if not a string
#     636     sheet = self.get_sheet_by_index(asheetname)
# --> 638 data = self.get_sheet_data(sheet, convert_float)
#     639 if hasattr(sheet, "close"):
#     640     # pyxlsb opens two TemporaryFiles
#     641     sheet.close()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/excel/_openpyxl.py:575, in OpenpyxlReader.get_sheet_data(self, sheet, convert_float)
#     573 data: list[list[Scalar]] = []
#     574 last_row_with_data = -1
# --> 575 for row_number, row in enumerate(sheet.rows):
#     576     converted_row = [self._convert_cell(cell, convert_float) for cell in row]
#     577     while converted_row and converted_row[-1] == "":
#     578         # trim trailing empty elements
#
# File ~/.local/lib/python3.10/site-packages/openpyxl/worksheet/_read_only.py:79, in ReadOnlyWorksheet._cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      75 src = self._get_source()
#      76 parser = WorkSheetParser(src, self._shared_strings,
#      77                          data_only=self.parent.data_only, epoch=self.parent.epoch,
#      78                          date_formats=self.parent._date_formats)
# ---> 79 for idx, row in parser.parse():
#      80     if max_row is not None and idx > max_row:
#      81         break
#
# File ~/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:155, in WorkSheetParser.parse(self)
#     153     element.clear()
#     154 elif tag_name == ROW_TAG:
# --> 155     row = self.parse_row(element)
#     156     element.clear()
#     157     yield row
#
# File ~/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:286, in WorkSheetParser.parse_row(self, row)
#     282 if keys - {'r', 'spans'}:
#     283     # don't create dimension objects unless they have relevant information
#     284     self.row_dimensions[str(self.row_counter)] = attrs
# --> 286 cells = [self.parse_cell(el) for el in row]
#     287 return self.row_counter, cells
#
# File ~/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:286, in <listcomp>(.0)
#     282 if keys - {'r', 'spans'}:
#     283     # don't create dimension objects unless they have relevant information
#     284     self.row_dimensions[str(self.row_counter)] = attrs
# --> 286 cells = [self.parse_cell(el) for el in row]
#     287 return self.row_counter, cells
#
# KeyboardInterrupt:

# %%
data['Price_per_unit_area'] = data['Price_per_unit_area'].astype(str).str.replace(',', '').astype(int)
data['Price'] = data['Price'].astype(str).str.replace(',', '').astype(int)
data['Size'].astype(str)
data['Size'] = data['Size'].str.removesuffix(' sq ft').str.replace(',', '').astype(int)

# %%
data2 = data.copy()

# %%
data = data2.copy()

# %% [markdown]
# - There are a few more binary attributes which we remove from consideration.
# - We also do not consider attributes which have a high variance and we cannot generalize them
# - `City_id` and `listing_domain_score` is irrelevant for learning rules too.

# %% [markdown]
# We drop attributes who have a number of distinct values but no higher level concept for the attribute
# We drop these attributes.

# %%
atrbs = ['Property_Name', 'Property_id', 'Project_URL', 'builder_id', 'Builder_name', 'Locality_ID', 'Longitude', 'Latitude', 'Sub_urban_ID', 'description', 'City_id', 'Listing_Category', 'is_plot', 'is_RERA_registered', 'is_Apartment', 'is_ready_to_move', 'is_commercial_Listing', 'is_PentaHouse', 'is_studio', 'listing_domain_score', 'No_of_BHK', 'Locality_Name', 'Sub_urban_name', 'Posted_On', 'Price_per_unit_area']

for att in atrbs:
    data.drop(att, axis=1, inplace=True)

# %% [markdown]
# We generalise attributes to higher level attributes

# %% [markdown]
# > Generalising Price Values (Ascending Concept Heirarchy)

# %%
_gold = ((data['Price'] <= 8000000000) & (data['Price'] >= 50000000))
_silver = ((data['Price'] < 50000000) & (data['Price'] >= 2000000))
_bronze = ((data['Price'] < 2000000) & (data['Price'] >= 100000))

data.loc[_gold, ['Price']] = 'Gold'
data.loc[_silver, ['Price']] = 'Silver'
data.loc[_bronze, ['Price']] = 'Bronze'

# %% [markdown]
# > Generalising Size Values

# %%
_large = ((data['Size'] <= 90000) & (data['Size'] >= 50000))
_medium = ((data['Size'] < 50000) & (data['Size'] >= 5000))
_small = ((data['Size'] < 5000) & (data['Size'] >= 100))

data.loc[_large, ['Size']] = 'Large'
data.loc[_medium, ['Size']] = 'Medium'
data.loc[_small, ['Size']] = 'Small'

# %% [markdown]
# > Removing Duplicates

# %%
data = data.drop_duplicates()
data
# Out:
#             Property_type     Property_status Property_building_status  \
# 0               Apartment  Under Construction                   ACTIVE
# 2               Apartment       Ready to move                   ACTIVE
# 25      Independent House  Under Construction                   ACTIVE
# 30                  Villa  Under Construction                   ACTIVE
# 33              Apartment  Under Construction                   ACTIVE
# ...                   ...                 ...                      ...
# 141777          Apartment       Ready to move                   ACTIVE
# 142027  Independent House       Ready to move                   ACTIVE
# 142253  Independent House       Ready to move                   ACTIVE
# 142841  Independent House  Under Construction                   ACTIVE
# 143113  Independent House       Ready to move                   ACTIVE
#
#         City_name   Price    Size is_furnished
# 0       Ahmedabad  Silver   Small  Unfurnished
# 2       Ahmedabad  Silver   Small  Unfurnished
# 25      Ahmedabad  Silver   Small  Unfurnished
# 30      Ahmedabad  Silver   Small  Unfurnished
# 33      Ahmedabad  Silver  Medium  Unfurnished
# ...           ...     ...     ...          ...
# 141777     Mumbai  Silver  Medium  Unfurnished
# 142027     Mumbai  Bronze   Small  Unfurnished
# 142253     Mumbai  Bronze   Small    Furnished
# 142841     Mumbai  Silver   Small    Furnished
# 143113     Mumbai    Gold   Small  Unfurnished
#
# [542 rows x 7 columns]

# %%
vals = ['Property_status', 'Property_building_status', 'is_furnished']
for att in vals:
    data.drop(att, axis=1, inplace=True)
data = data.drop_duplicates()
data

# %% [markdown]
# > Generalising City Values

# %%
techCity_cond = ((data['City_name'] == 'Mumbai' ) | (data['City_name'] == 'Bangalore') | (data['City_name'] == 'Ahmedabad') | (data['City_name'] == 'Hyderabad'))
otherCity_cond = ((data['City_name'] == 'Delhi') | (data['City_name'] == 'Kolkata') | (data['City_name'] == 'Chennai') | (data['City_name'] == 'Lucknow'))

data.loc[techCity_cond, ['City_name']] = 'Tech City'
data.loc[otherCity_cond, ['City_name']] = 'Other City'

# %%
data = data.drop_duplicates()
data
# Out:
#            Property_type   City_name   Price    Size
# 0              Apartment   Tech City  Silver   Small
# 25     Independent House   Tech City  Silver   Small
# 30                 Villa   Tech City  Silver   Small
# 33             Apartment   Tech City  Silver  Medium
# 61             Apartment   Tech City  Bronze   Small
# 116                Villa   Tech City  Silver  Medium
# 164    Independent Floor   Tech City  Silver   Small
# 230     Residential Plot   Tech City  Bronze   Small
# 232     Residential Plot   Tech City  Silver   Small
# 235     Residential Plot   Tech City  Silver  Medium
# 318            Apartment   Tech City    Gold  Medium
# 341                Villa   Tech City    Gold   Small
# 475     Residential Plot   Tech City  Silver   Large
# 521            Apartment   Tech City    Gold   Small
# 529    Independent House   Tech City  Silver  Medium
# 931                Villa   Tech City    Gold  Medium
# 1106   Independent House   Tech City    Gold  Medium
# 1168   Independent House   Tech City    Gold   Small
# 1572    Residential Plot   Tech City    Gold  Medium
# 3758    Residential Plot   Tech City    Gold   Small
# 6222   Independent Floor   Tech City  Bronze   Small
# 6611    Residential Plot   Tech City  Bronze  Medium
# 12379  Independent Floor   Tech City    Gold   Small
# 25440              Villa   Tech City  Bronze   Small
# 26435  Independent House   Tech City  Bronze   Small
# 27631              Villa  Other City  Silver   Small
# 27635   Residential Plot  Other City  Silver   Small
# 27636          Apartment  Other City  Silver   Small
# 27643   Residential Plot  Other City  Bronze   Small
# 27647  Independent House  Other City  Silver   Small
# 27694              Villa  Other City  Bronze   Small
# 27732              Villa  Other City    Gold  Medium
# 28488   Residential Plot  Other City  Silver  Medium
# 28521          Apartment  Other City  Bronze   Small
# 28644          Apartment  Other City    Gold   Small
# 28888  Independent House  Other City    Gold  Medium
# 29146  Independent House  Other City  Bronze   Small
# 29535          Apartment  Other City  Silver  Medium
# 29762          Apartment  Other City    Gold  Medium
# 30267  Independent Floor  Other City  Silver   Small
# 30604              Villa  Other City  Silver  Medium
# 30641              Villa  Other City    Gold   Small
# 35064   Residential Plot  Other City    Gold  Medium
# 41059  Independent Floor  Other City    Gold   Small
# 41219  Independent Floor  Other City  Bronze   Small
# 42534   Residential Plot  Other City    Gold   Small
# 44930  Independent Floor  Other City    Gold  Medium
# 45807  Independent House  Other City    Gold   Small
# 50643  Independent Floor   Tech City    Gold  Medium
# 57924   Residential Plot  Other City  Bronze  Medium
# 59339  Independent House  Other City  Silver  Medium

# %%
data[data['Property_type'] =='Villa']
# Out:
#       Property_type   City_name   Price    Size
# 30            Villa   Tech City  Silver   Small
# 116           Villa   Tech City  Silver  Medium
# 341           Villa   Tech City    Gold   Small
# 931           Villa   Tech City    Gold  Medium
# 25440         Villa   Tech City  Bronze   Small
# 27631         Villa  Other City  Silver   Small
# 27694         Villa  Other City  Bronze   Small
# 27732         Villa  Other City    Gold  Medium
# 30604         Villa  Other City  Silver  Medium
# 30641         Villa  Other City    Gold   Small

# %% [markdown]
# the several tuples can be reduced into one by taking the distinct values of that attribute as a set.

# %%
for i in range(len(data)):
    for j in range(i+1, len(data)):
        if data.iloc[i]['Property_type'] == data.iloc[j]['Property_type']:
            if data.iloc[i]['City_name'] == data.iloc[j]['City_name']:
                if data.iloc[i]['Size'] == data.iloc[j]['Size']:
                    if data.iloc[i]['Price'].find(data.iloc[j]['Price']) != -1 or data.iloc[j]['Price'].find(data.iloc[i]['Price']) != -1:
                        if data.iloc[i]['Price'].find(data.iloc[j]['Price']) != -1:
                            data.iloc[i]['Price'] = data.iloc[j]['Price']
                        else:
                            data.iloc[j]['Price'] = data.iloc[i]['Price']
                    else:
                        data.iloc[i]['Price'] = data.iloc[i]['Price'] + ', ' + data.iloc[j]['Price']
                        data.iloc[j]['Price'] = data.iloc[i]['Price']

# %%
for i in range(len(data.index)):
    for j in range(i+1, len(data.index)):
        if data.iloc[i]['Price'].find(data.iloc[j]['Price']) != -1:
            data.iloc[j]['Price'] = data.iloc[i]['Price']

# %%
data = data.drop_duplicates()
data
# Out:
# 21
#            Property_type   City_name                 Price    Size
# 0              Apartment   Tech City  Silver, Bronze, Gold   Small
# 25     Independent House   Tech City  Silver, Gold, Bronze   Small
# 30                 Villa   Tech City  Silver, Gold, Bronze   Small
# 33             Apartment   Tech City  Silver, Gold, Bronze  Medium
# 116                Villa   Tech City  Silver, Gold, Bronze  Medium
# 164    Independent Floor   Tech City  Silver, Bronze, Gold   Small
# 230     Residential Plot   Tech City  Bronze, Silver, Gold   Small
# 235     Residential Plot   Tech City  Silver, Gold, Bronze  Medium
# 475     Residential Plot   Tech City  Silver, Bronze, Gold   Large
# 529    Independent House   Tech City  Silver, Gold, Bronze  Medium
# 27631              Villa  Other City  Silver, Bronze, Gold   Small
# 27635   Residential Plot  Other City  Silver, Bronze, Gold   Small
# 27636          Apartment  Other City  Silver, Bronze, Gold   Small
# 27647  Independent House  Other City  Silver, Bronze, Gold   Small
# 27732              Villa  Other City          Gold, Silver  Medium
# 28488   Residential Plot  Other City  Silver, Gold, Bronze  Medium
# 28888  Independent House  Other City          Gold, Silver  Medium
# 29535          Apartment  Other City  Silver, Gold, Bronze  Medium
# 30267  Independent Floor  Other City  Silver, Gold, Bronze   Small
# 44930  Independent Floor  Other City  Silver, Bronze, Gold  Medium
# 50643  Independent Floor   Tech City  Silver, Bronze, Gold  Medium

# %%
data[data['Property_type'] == 'Villa']
# Out:
#       Property_type   City_name                 Price    Size
# 30            Villa   Tech City  Silver, Gold, Bronze   Small
# 116           Villa   Tech City  Silver, Gold, Bronze  Medium
# 27631         Villa  Other City  Silver, Bronze, Gold   Small
# 27732         Villa  Other City          Gold, Silver  Medium

# %%
for i in range(len(data)):
    if data.iloc[i]['Price'].find('Luxury') != -1 and data.iloc[i]['Price'].find('Budget') != -1 and data.iloc[i]['Price'].find('Premium') != -1:
        data.iloc[i]['Price'] = 'Any'

data[data['Property_type'] == 'Villa']
# Out:
#       Property_type   City_name                 Price    Size
# 30            Villa   Tech City  Silver, Gold, Bronze   Small
# 116           Villa   Tech City  Silver, Gold, Bronze  Medium
# 27631         Villa  Other City  Silver, Bronze, Gold   Small
# 27732         Villa  Other City          Gold, Silver  Medium
